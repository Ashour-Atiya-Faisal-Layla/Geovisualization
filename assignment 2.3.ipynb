# %%
# Relevant imports
import shutil
import seaborn as sns
import pandas as pd
import numpy as np



# Load the .csv file into a pandas dataframe named afl
afl = pd.read_csv('fryziggafl.csv')

afl_post_2000 = afl[(afl['match_date'] > '2000-01-01')]
afl_pre_2000 = afl[(afl['match_date'] < '2000-01-01')]
# Out:
# C:\Users\ashou\AppData\Local\Temp\ipykernel_11752\2205259274.py:10: DtypeWarning: Columns (8,18,24,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   afl = pd.read_csv('fryziggafl.csv')
#    Unnamed: 0    venue_name  match_id match_home_team match_away_team  \
# 0           1  Brunswick St         1         Fitzroy         Carlton
# 1           2  Brunswick St         1         Fitzroy         Carlton
# 2           3  Brunswick St         1         Fitzroy         Carlton
# 3           4  Brunswick St         1         Fitzroy         Carlton
# 4           5  Brunswick St         1         Fitzroy         Carlton
#
#    match_date match_local_time  match_attendance match_round  \
# 0  1897-05-08         15:00:00              3000           1
# 1  1897-05-08         15:00:00              3000           1
# 2  1897-05-08         15:00:00              3000           1
# 3  1897-05-08         15:00:00              3000           1
# ...

# %%
afl
# Out:
#         Unnamed: 0    venue_name  match_id match_home_team match_away_team  \
# 0                1  Brunswick St         1         Fitzroy         Carlton
# 1                2  Brunswick St         1         Fitzroy         Carlton
# 2                3  Brunswick St         1         Fitzroy         Carlton
# 3                4  Brunswick St         1         Fitzroy         Carlton
# 4                5  Brunswick St         1         Fitzroy         Carlton
# ...            ...           ...       ...             ...             ...
# 655658      655659           MCG     16355         Geelong          Sydney
# 655659      655660           MCG     16355         Geelong          Sydney
# 655660      655661           MCG     16355         Geelong          Sydney
# 655661      655662           MCG     16355         Geelong          Sydney
# 655662      655663           MCG     16355         Geelong          Sydney
#
# ...

# %%
ax = sns.scatterplot(x = 'match_home_team_goals' , y = 'match_home_team_score' , data = afl)
# Out:
# C:\Users\ashou\OneDrive - LA TROBE UNIVERSITY\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ax = sns.scatterplot(x = 'match_home_team_goals' , y = 'match_home_team_score' , data = afl , hue = 'match_margin' )
